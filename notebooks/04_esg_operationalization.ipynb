# %% [markdown]
# # 04_esg_operationalization
#
# Notebook này thực hiện các nội dung sau:
#
# - Load candidate ESG indicators.
# - Rà soát candidate ESG indicators.
# - Thiết kế operational mapping.
# - Thiết kế feature specification.
# - Xuất các tài liệu phục vụ feature engineering.
#
# Notebook này không thực hiện:
#
# - Feature engineering.
# - Seller-level aggregation.
# - ESG score calculation.
# - AHP weighting.
# - Machine learning.

# %% [markdown]
# # Phần 0. Set up
#
# Thiết lập môi trường xử lý dữ liệu và cấu hình hiển thị cho notebook.

# %%
# Import thư viện.

import warnings

from pathlib import Path

import numpy as np
import pandas as pd

# %%
# Thiết lập cấu hình hiển thị.

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", 150)

# %% [markdown]
# # PHẦN 1. LOAD ESG KNOWLEDGE BASE
#
# Notebook này **không xây dựng mới ESG Knowledge Base**.
#
# Toàn bộ tri thức ESG đã được xây dựng và lưu trữ trong Notebook 03.
#
# Trong phần này, các Knowledge Base sẽ được nạp vào hệ thống nhằm phục vụ quá trình:
#
# - Review Candidate ESG Indicators
# - Operational Measurement Design
# - Operational Mapping
# - Feature Specification
#
# Các Knowledge Base được sử dụng bao gồm:
#
# 1. ESG Keyword Dictionary
# 2. Sustainable Material Dictionary
# 3. Eco Label Dictionary
# 4. Fashion ESG Complaint Ontology

# %%
# Thiết lập đường dẫn

project_path = Path("..")

knowledge_base_path = (
    project_path
    / "Dataset"
    / "processed"
    / "ESG_Knowledge_Base"
)

esg_keyword_dictionary_path = (
    knowledge_base_path
    / "esg_keyword_dictionary.csv"
)

sustainable_material_dictionary_path = (
    knowledge_base_path
    / "sustainable_material_dictionary.csv"
)

eco_label_dictionary_path = (
    knowledge_base_path
    / "eco_label_dictionary.csv"
)

fashion_esg_complaint_ontology_path = (
    knowledge_base_path
    / "fashion_esg_complaint_ontology.csv"
)

# %%
esg_keyword_dictionary_df = pd.read_csv(
    esg_keyword_dictionary_path
)

sustainable_material_dictionary_df = pd.read_csv(
    sustainable_material_dictionary_path
)

eco_label_dictionary_df = pd.read_csv(
    eco_label_dictionary_path
)

fashion_esg_complaint_ontology_df = pd.read_csv(
    fashion_esg_complaint_ontology_path
)

# %%
knowledge_base_summary_df = pd.DataFrame({

    "Knowledge Base":[

        "ESG Keyword Dictionary",

        "Sustainable Material Dictionary",

        "Eco Label Dictionary",

        "Fashion ESG Complaint Ontology"

    ],

    "Records":[

        len(esg_keyword_dictionary_df),

        len(sustainable_material_dictionary_df),

        len(eco_label_dictionary_df),

        len(fashion_esg_complaint_ontology_df)

    ],

    "Description":[

        "General ESG keyword lexicon",

        "Sustainable fashion materials",

        "Eco labels and sustainability certifications",

        "Fashion ESG complaint concepts"

    ]

})

display(
    knowledge_base_summary_df
)
# Out:
#                     Knowledge Base  Records                                   Description
# 0           ESG Keyword Dictionary       45                   General ESG keyword lexicon
# 1  Sustainable Material Dictionary       14                 Sustainable fashion materials
# 2             Eco Label Dictionary        9  Eco labels and sustainability certifications
# 3   Fashion ESG Complaint Ontology        7                Fashion ESG complaint concepts

# %% [markdown]
# # PHẦN 2. REVIEW CANDIDATE ESG INDICATORS
#
# Sau khi xây dựng các ESG Knowledge Base trong Notebook 03, bước tiếp theo là rà soát các nguồn tri thức nhằm xác định những Candidate ESG Indicators có thể đo lường trên dữ liệu Amazon Fashion.
#
# Mỗi Candidate Indicator phải thỏa mãn các tiêu chí:
#
# - Có cơ sở từ tài liệu ESG hoặc tri thức đã xây dựng.
# - Có thể quan sát được trên dữ liệu Amazon.
# - Có khả năng chuyển đổi thành đặc trưng định lượng (Feature).
# - Phù hợp với mục tiêu xây dựng mô hình chấm điểm ESG cho nhà bán hàng.

# %%
knowledge_base_review_df = pd.DataFrame({

    "Knowledge Base":[

        "ESG Keyword Dictionary",

        "Sustainable Material Dictionary",

        "Eco Label Dictionary",

        "Fashion ESG Complaint Ontology"

    ],

    "Primary Purpose":[

        "General ESG concepts",

        "Sustainable material identification",

        "Eco-label identification",

        "Customer complaint identification"

    ],

    "Main ESG Dimension":[

        "E / S / G",

        "Environmental",

        "Environmental",

        "Environmental / Social / Governance"

    ]

})

display(
    knowledge_base_review_df
)
# Out:
#                     Knowledge Base                      Primary Purpose                   Main ESG Dimension
# 0           ESG Keyword Dictionary                 General ESG concepts                            E / S / G
# 1  Sustainable Material Dictionary  Sustainable material identification                        Environmental
# 2             Eco Label Dictionary             Eco-label identification                        Environmental
# 3   Fashion ESG Complaint Ontology    Customer complaint identification  Environmental / Social / Governance

# %%
candidate_indicator_df = pd.DataFrame({

    "Candidate Indicator":[

        "Environmental Sustainability",

        "Sustainable Material Adoption",

        "Eco-label Adoption",

        "Product Quality Responsibility",

        "Product Safety",

        "Customer Service Governance",

        "Operational Governance"

    ],

    "Primary Knowledge Base":[

        "ESG Keyword Dictionary",

        "Sustainable Material Dictionary",

        "Eco Label Dictionary",

        "Fashion ESG Complaint Ontology",

        "Fashion ESG Complaint Ontology",

        "Fashion ESG Complaint Ontology",

        "ESG Keyword Dictionary + Complaint Ontology"

    ],

    "ESG Dimension":[

        "E",

        "E",

        "E",

        "S",

        "S",

        "G",

        "G"

    ]

})

display(
    candidate_indicator_df
)
# Out:
#               Candidate Indicator                       Primary Knowledge Base ESG Dimension
# 0    Environmental Sustainability                       ESG Keyword Dictionary             E
# 1   Sustainable Material Adoption              Sustainable Material Dictionary             E
# 2              Eco-label Adoption                         Eco Label Dictionary             E
# 3  Product Quality Responsibility               Fashion ESG Complaint Ontology             S
# 4                  Product Safety               Fashion ESG Complaint Ontology             S
# 5     Customer Service Governance               Fashion ESG Complaint Ontology             G
# 6          Operational Governance  ESG Keyword Dictionary + Complaint Ontology             G

# %%
candidate_indicator_df["Operational Evidence"] = [

    "Environmental keywords",

    "Organic cotton, recycled polyester, lyocell...",

    "JOIN LIFE, Organic Cotton, ECOVERO...",

    "Poor quality, product damage",

    "Chemical smell",

    "Poor customer service",

    "Risk, policy, counterfeit, wrong size"

]

display(
    candidate_indicator_df)
# Out:
#               Candidate Indicator                       Primary Knowledge Base ESG Dimension                            Operational Evidence
# 0    Environmental Sustainability                       ESG Keyword Dictionary             E                          Environmental keywords
# 1   Sustainable Material Adoption              Sustainable Material Dictionary             E  Organic cotton, recycled polyester, lyocell...
# 2              Eco-label Adoption                         Eco Label Dictionary             E           JOIN LIFE, Organic Cotton, ECOVERO...
# 3  Product Quality Responsibility               Fashion ESG Complaint Ontology             S                    Poor quality, product damage
# 4                  Product Safety               Fashion ESG Complaint Ontology             S                                  Chemical smell
# ...

# %% [markdown]
# # PHẦN 3. OPERATIONAL MEASUREMENT DESIGN
#
# Sau khi xác định các Candidate ESG Indicators, bước tiếp theo là thiết kế phương pháp đo lường (Operational Measurement).
#
# Mỗi Candidate Indicator sẽ được chuyển đổi thành một hoặc nhiều phép đo có thể tính toán trực tiếp từ dữ liệu Amazon thông qua các ESG Knowledge Base.
#
# Operational Measurement đóng vai trò là cầu nối giữa khái niệm ESG trong lý thuyết và các đặc trưng định lượng (Features) được sử dụng trong Machine Learning.

# %%
operational_measurement_df = pd.DataFrame({

    "Candidate Indicator":[
        "Environmental Sustainability",
        "Sustainable Material Adoption",
        "Eco-label Adoption",
        "Product Quality Responsibility",
        "Product Safety",
        "Customer Service Governance",
        "Operational Governance"

    ],

    "Measurement":[
        "Count environmental ESG keywords",
        "Count sustainable materials",
        "Count eco-label mentions",
        "Count product quality complaints",
        "Count product safety complaints",
        "Count customer service complaints",
        "Count governance-related keywords and complaints"
    ],

    "Knowledge Base":[
        "ESG Keyword Dictionary",
        "Sustainable Material Dictionary",
        "Eco Label Dictionary",
        "Fashion ESG Complaint Ontology",
        "Fashion ESG Complaint Ontology",
        "Fashion ESG Complaint Ontology",
        "ESG Keyword Dictionary + Fashion ESG Complaint Ontology"
    ]

})

display(
    operational_measurement_df
)
# Out:
#               Candidate Indicator                                       Measurement                                           Knowledge Base
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %%
operational_measurement_df["Measurement Level"] = [

    "Frequency",
    "Frequency",
    "Frequency",
    "Frequency",
    "Frequency",
    "Frequency",
    "Frequency"

]

display(
    operational_measurement_df
)
# Out:
#               Candidate Indicator                                       Measurement                                           Knowledge Base  \
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %%
operational_measurement_df["Measurement Unit"] = [

    "Keyword Count",
    "Material Count",
    "Eco-label Count",
    "Complaint Count",
    "Complaint Count",
    "Complaint Count",
    "Keyword + Complaint Count"

]

display(
    operational_measurement_df
)
# Out:
#               Candidate Indicator                                       Measurement                                           Knowledge Base  \
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %%
operational_measurement_df = operational_measurement_df[

    [

        "Candidate Indicator",
        "Measurement",
        "Measurement Unit",
        "Measurement Level",
        "Knowledge Base"

    ]

]

display(
    operational_measurement_df
)
# Out:
#               Candidate Indicator                                       Measurement           Measurement Unit Measurement Level  \
# 0    Environmental Sustainability                  Count environmental ESG keywords              Keyword Count         Frequency
# 1   Sustainable Material Adoption                       Count sustainable materials             Material Count         Frequency
# 2              Eco-label Adoption                          Count eco-label mentions            Eco-label Count         Frequency
# 3  Product Quality Responsibility                  Count product quality complaints            Complaint Count         Frequency
# 4                  Product Safety                   Count product safety complaints            Complaint Count         Frequency
# 5     Customer Service Governance                 Count customer service complaints            Complaint Count         Frequency
# ...

# %% [markdown]
# # PHẦN 4. OPERATIONAL MAPPING
#
# Sau khi xác định các Operational Measurements, bước tiếp theo là xây dựng Operational Mapping.
#
# Operational Mapping xác định mối liên hệ giữa:
#
# - Candidate ESG Indicator;
# - Operational Measurement;
# - ESG Knowledge Base;
# - Trường dữ liệu (Dataset Field) trên Amazon.
#
# Kết quả của bước này sẽ là cơ sở để triển khai Feature Engineering trong Notebook tiếp theo.

# %%
operational_mapping_df = pd.DataFrame({

    "Candidate Indicator":[
        "Environmental Sustainability",
        "Sustainable Material Adoption",
        "Eco-label Adoption",
        "Product Quality Responsibility",
        "Product Safety",
        "Customer Service Governance",
        "Operational Governance"
    ],

    "Operational Measurement":[
        "Count environmental ESG keywords",
        "Count sustainable materials",
        "Count eco-label mentions",
        "Count product quality complaints",
        "Count product safety complaints",
        "Count customer service complaints",
        "Count governance-related keywords and complaints"
    ],

    "Knowledge Base":[
        "ESG Keyword Dictionary",
        "Sustainable Material Dictionary",
        "Eco Label Dictionary",
        "Fashion ESG Complaint Ontology",
        "Fashion ESG Complaint Ontology",
        "Fashion ESG Complaint Ontology",
        "ESG Keyword Dictionary + Fashion ESG Complaint Ontology"
    ],

    "Amazon Dataset Field":[
        "title + text",
        "material",
        "joinlife_title + joinlife_desc",
        "text",
        "text",
        "text",
        "title + text"
    ]

})

display(
    operational_mapping_df
)
# Out:
#               Candidate Indicator                           Operational Measurement                                           Knowledge Base  \
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %%
operational_mapping_df["Matching Strategy"] = [

    "Keyword Matching",
    "Dictionary Matching",
    "Dictionary Matching",
    "Complaint Ontology Matching",
    "Complaint Ontology Matching",
    "Complaint Ontology Matching",
    "Hybrid Matching"

]

display(
    operational_mapping_df
)
# Out:
#               Candidate Indicator                           Operational Measurement                                           Knowledge Base  \
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %%
operational_mapping_df["Output Feature"] = [

    "environmental_keyword_count",
    "sustainable_material_count",
    "eco_label_count",
    "product_quality_complaint_count",
    "product_safety_complaint_count",
    "customer_service_complaint_count",
    "governance_keyword_count"

]

display(
    operational_mapping_df
)
# Out:
#               Candidate Indicator                           Operational Measurement                                           Knowledge Base  \
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %%
operational_mapping_df = operational_mapping_df[

    [

        "Candidate Indicator",
        "Operational Measurement",
        "Knowledge Base",
        "Amazon Dataset Field",
        "Matching Strategy",
        "Output Feature"

    ]

]

display(
    operational_mapping_df
)
# Out:
#               Candidate Indicator                           Operational Measurement                                           Knowledge Base  \
# 0    Environmental Sustainability                  Count environmental ESG keywords                                   ESG Keyword Dictionary
# 1   Sustainable Material Adoption                       Count sustainable materials                          Sustainable Material Dictionary
# 2              Eco-label Adoption                          Count eco-label mentions                                     Eco Label Dictionary
# 3  Product Quality Responsibility                  Count product quality complaints                           Fashion ESG Complaint Ontology
# 4                  Product Safety                   Count product safety complaints                           Fashion ESG Complaint Ontology
# ...

# %% [markdown]
# # PHẦN 5. FEATURE SPECIFICATION
#
# Sau khi hoàn thành Operational Mapping, bước cuối cùng là đặc tả các đặc trưng (Features) sẽ được xây dựng trong giai đoạn Feature Engineering.
#
# Mỗi Feature được mô tả bao gồm:
#
# - tên đặc trưng;
# - kiểu dữ liệu;
# - nguồn tri thức;
# - phương pháp tính toán;
# - vai trò trong mô hình chấm điểm ESG.
#
# Các Feature này sẽ được triển khai trong Notebook Feature Engineering.

# %%
feature_specification_df = pd.DataFrame({

    "Feature":[

        "environmental_keyword_count",
        "sustainable_material_count",
        "eco_label_count",
        "product_quality_complaint_count",
        "product_damage_complaint_count",
        "product_safety_complaint_count",
        "customer_service_complaint_count",
        "counterfeit_complaint_count",
        "packaging_complaint_count",
        "governance_keyword_count"

    ],

    "Data Type":[

        "Integer",
        "Integer",
        "Integer",
        "Integer",
        "Integer",
        "Integer",
        "Integer",
        "Integer",
        "Integer",
        "Integer"

    ],

    "Measurement":[

        "Keyword Frequency",
        "Dictionary Frequency",
        "Dictionary Frequency",
        "Complaint Frequency",
        "Complaint Frequency",
        "Complaint Frequency",
        "Complaint Frequency",
        "Complaint Frequency",
        "Complaint Frequency",
        "Keyword + Complaint Frequency"

    ],

    "ESG Dimension":[

        "E",
        "E",
        "E",
        "S",
        "S",
        "S",
        "G",
        "G",
        "E",
        "G"

    ]

})

display(
    feature_specification_df
)
# Out:
#                             Feature Data Type                    Measurement ESG Dimension
# 0       environmental_keyword_count   Integer              Keyword Frequency             E
# 1        sustainable_material_count   Integer           Dictionary Frequency             E
# 2                   eco_label_count   Integer           Dictionary Frequency             E
# 3   product_quality_complaint_count   Integer            Complaint Frequency             S
# 4    product_damage_complaint_count   Integer            Complaint Frequency             S
# 5    product_safety_complaint_count   Integer            Complaint Frequency             S
# 6  customer_service_complaint_count   Integer            Complaint Frequency             G
# 7       counterfeit_complaint_count   Integer            Complaint Frequency             G
# 8         packaging_complaint_count   Integer            Complaint Frequency             E
# ...

# %%
feature_specification_df["Knowledge Base"] = [

    "ESG Keyword Dictionary",
    "Sustainable Material Dictionary",
    "Eco Label Dictionary",
    "Fashion ESG Complaint Ontology",
    "Fashion ESG Complaint Ontology",
    "Fashion ESG Complaint Ontology",
    "Fashion ESG Complaint Ontology",
    "Fashion ESG Complaint Ontology",
    "Fashion ESG Complaint Ontology",
    "ESG Keyword Dictionary + Fashion ESG Complaint Ontology"

]

display(
    feature_specification_df
)
# Out:
#                             Feature Data Type                    Measurement ESG Dimension                                           Knowledge Base
# 0       environmental_keyword_count   Integer              Keyword Frequency             E                                   ESG Keyword Dictionary
# 1        sustainable_material_count   Integer           Dictionary Frequency             E                          Sustainable Material Dictionary
# 2                   eco_label_count   Integer           Dictionary Frequency             E                                     Eco Label Dictionary
# 3   product_quality_complaint_count   Integer            Complaint Frequency             S                           Fashion ESG Complaint Ontology
# 4    product_damage_complaint_count   Integer            Complaint Frequency             S                           Fashion ESG Complaint Ontology
# ...

# %%
feature_specification_df = feature_specification_df[

    [

        "Feature",
        "ESG Dimension",
        "Data Type",
        "Measurement",
        "Knowledge Base"

    ]

]

display(
    feature_specification_df
)
# Out:
#                             Feature ESG Dimension Data Type                    Measurement                                           Knowledge Base
# 0       environmental_keyword_count             E   Integer              Keyword Frequency                                   ESG Keyword Dictionary
# 1        sustainable_material_count             E   Integer           Dictionary Frequency                          Sustainable Material Dictionary
# 2                   eco_label_count             E   Integer           Dictionary Frequency                                     Eco Label Dictionary
# 3   product_quality_complaint_count             S   Integer            Complaint Frequency                           Fashion ESG Complaint Ontology
# 4    product_damage_complaint_count             S   Integer            Complaint Frequency                           Fashion ESG Complaint Ontology
# ...

# %%
feature_specification_output_path = (
    project_path
    / "Dataset"
    / "processed"
    / "ESG_Operationalization"
    / "feature_specification.csv"
)

feature_specification_output_path.parent.mkdir(
    parents=True,
    exist_ok=True
)

feature_specification_df.to_csv(
    feature_specification_output_path,
    index=False,
    encoding="utf-8-sig"
)

print(
    f"Feature Specification saved to:\n{feature_specification_output_path}"
)
# Out:
# Feature Specification saved to:
# ..\Dataset\processed\ESG_Operationalization\feature_specification.csv
